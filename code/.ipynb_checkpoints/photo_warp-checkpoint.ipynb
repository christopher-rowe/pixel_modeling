# %%
# import libraries
import os
import PIL
from PIL import Image
import numpy as np
from numpy import asarray
from numpy import clip
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn import linear_model

# %%
def processImage(file, grayscale = True):
    
    img = Image.open(file).convert("L")
        
    # resize image
    basewidth = 280
    wpercent = (basewidth / float(img.size[0]))
    hsize = int((float(img.size[1]) * float(wpercent)))
    img = img.resize((basewidth, 372), PIL.Image.ANTIALIAS)
    
    return img

def LRWarp(img, prop_row, prop_col, iterations, verbose = False):
    
    # convert image to array
    img_array = asarray(img)
    pred_img = np.empty(((img_array.shape[0], img_array.shape[1], iterations)))
            
    for i in range(iterations):
        if verbose == True:
            print("Processing Iteration #", i + 1)
        for col in range(img_array.shape[1]):
            X = np.delete(img_array, col, axis=1)
            y = img_array[:, col]
            row_sample = np.random.choice(range(X.shape[0]), size=round(prop_row*X.shape[0]), replace = False)
            col_sample = np.random.choice(range(X.shape[1]), size=round(prop_col*X.shape[1]), replace = False)
            X_rc_samp = X[row_sample, :]
            X_rc_samp = X_rc_samp[:, col_sample]
            y_r_samp = y[row_sample]
            reg = LinearRegression().fit(X_rc_samp, y_r_samp)
            X_c_samp = X[:, col_sample]
            pred_img[:, col, i] = reg.predict(X_c_samp)
            
    pred_img_flat = pred_img.mean(axis = 2)     
    pred_img_flat = np.round(pred_img_flat)
    pred_img_flat = np.clip(pred_img_flat, 0, 255)
    result = Image.fromarray(np.uint8(pred_img_flat))
    
    return result

def LRWarp2(img1, img2, prop_row, prop_col, iterations, verbose = False):
    
    # convert image to array
    img1_array = asarray(img1)
    img2_array = asarray(img2)
    pred_img = np.empty(((img1_array.shape[0], img1_array.shape[1], iterations)))
            
    for i in range(iterations):
        if verbose == True:
            print("Processing Iteration #", i + 1)
        for col in range(img1_array.shape[1]):
            X1 = np.delete(img1_array, col, axis=1)
            X2 = np.delete(img2_array, col, axis=1)
            y1 = img1_array[:, col]
            row_sample = np.random.choice(range(X1.shape[0]), size=round(prop_row*X1.shape[0]), replace = False)
            col_sample = np.random.choice(range(X1.shape[1]), size=round(prop_col*X1.shape[1]), replace = False)
            X1_rc_samp = X1[row_sample, :]
            X1_rc_samp = X1_rc_samp[:, col_sample]
            y1_r_samp = y1[row_sample]
            reg = LinearRegression().fit(X1_rc_samp, y1_r_samp)
            X2_c_samp = X2[:, col_sample]
            pred_img[:, col, i] = reg.predict(X2_c_samp)
            
    pred_img_flat = pred_img.mean(axis = 2)     
    pred_img_flat = np.round(pred_img_flat)
    pred_img_flat = np.clip(pred_img_flat, 0, 255)
    result = Image.fromarray(np.uint8(pred_img_flat))
    
    return result

# %%
# import photo
os.chdir('/Users/chrisrowe/Documents/personal_projects/photo_warp/photos/')

# open and process images
img_cr = processImage('cr.jpg')
img_stump = processImage('stump.jpg')

# %%
LRWarp(img_cr, prop_row = 0.2, prop_col = 0.03, 
       iterations = 5, verbose = False)
# Out:
# <PIL.Image.Image image mode=L size=280x372 at 0x7FB5686F56D0>

# %%
lrw.save('lr_2_03_100.jpg')

# %%
LRWarp2(img_stump, img_cr, prop_row = 0.1, prop_col = 0.1, 
       iterations = 100, verbose = False)
# Out:
# <PIL.Image.Image image mode=L size=280x372 at 0x7FBC3CD12C10>

# %%
from sklearn.linear_model import ElasticNet
import xgboost as xgb

# %%
X = np.empty((img_t.shape[0]*img_t.shape[1], 2))
y = np.empty(img_t.shape[0]*img_t.shape[1])
pred_y = np.empty(img_t.shape[0]*img_t.shape[1])
pred_img = np.empty(img_t.shape)

i = 0
for r in range(img_t.shape[0]):
    for c in range(img_t.shape[1]):
        X[i, 0] = r
        X[i, 1] = c
        y[i] = img_t[r, c]
        i = i + 1
poly = PolynomialFeatures(5)
X = poly.fit_transform(X)
#reg = LinearRegression().fit(X, y)
#reg = ElasticNet(max_iter = 100000).fit(X, y)
model = xgb.XGBRegressor(objective='reg:squarederror', 
                         eta = 0.01, 
                         max_depth = 20)
reg = reg.fit(X, y)
pred_y = reg.predict(X)
pred_y = np.round(pred_y)
pred_y = np.clip(pred_y, 0, 255)

i = 0
for r in range(img_t.shape[0]):
    for c in range(img_t.shape[1]):
        pred_img[r, c] = pred_y[i]
        i = i + 1


result = Image.fromarray(np.uint8(pred_img))
#result

# %%
transpose = False

# prep data from image
img_t = asarray(img_cr)
if transpose == True:
    img_t = img_t.T
X = np.empty((img_t.shape[0]*img_t.shape[1], 2))
y = np.empty(img_t.shape[0]*img_t.shape[1])
pred_y = np.empty(img_t.shape[0]*img_t.shape[1])
pred_img = np.empty(img_t.shape)

i = 0
for r in range(img_t.shape[0]):
    for c in range(img_t.shape[1]):
        X[i, 0] = r
        X[i, 1] = c
        y[i] = img_t[r, c]
        i = i + 1
poly = PolynomialFeatures(5)
X = poly.fit_transform(X)

# %%
#reg = LinearRegression().fit(X, y)
#reg = ElasticNet(max_iter = 100000).fit(X, y)
model = xgb.XGBRegressor(objective='reg:squarederror', 
                         n_estimators = 50,
                         eta = 5, 
                         max_depth = 100)
reg = reg.fit(X, y)
pred_y = reg.predict(X)
pred_y = np.round(pred_y)
pred_y = np.clip(pred_y, 0, 255)

i = 0
for r in range(img_t.shape[0]):
    for c in range(img_t.shape[1]):
        pred_img[r, c] = pred_y[i]
        i = i + 1

if transpose == True:
    pred_img = pred_img.T        

result = Image.fromarray(np.uint8(pred_img))
result
# Out:
# <PIL.Image.Image image mode=L size=280x372 at 0x7FB55A027ED0>

# %%
img_cr.save("og.jpg")

# %%
all = np.hstack((img_cr, lrw))
all = np.hstack((all, result))
trio = Image.fromarray(np.uint8(all))
trio.save('trio.jpg')

# %%
# Out:
# (372, 840)

# %%
# models
from mlens.ensemble import SuperLearner
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

# model selection
from sklearn.model_selection import train_test_split, StratifiedKFold, RandomizedSearchCV, GridSearchCV

# metrics
from sklearn.metrics import mean_squared_error

# other
from sklearn.impute import KNNImputer
# Out:
# [MLENS] backend: threading

# %%
#elasticnet = ElasticNet(max_iter = 100000).fit(X, y)
lr = LinearRegression().fit(X, y)
rf = RandomForestRegressor().fit(X, y)
print("done!")
xgb = XGBRegressor(objective='reg:squarederror').fit(X, y)
# Out:
# done!

# %%
# initiate superlearner
sl = SuperLearner(folds = 10, random_state = 6053, verbose = 2)

# Build the first layer
sl.add([lr, xgb])

# Attach the final meta estimator
sl.add_meta(LinearRegression())

# fit
sl.fit(X, y)

# predict
pred_y = sl.predict(X)
# Out:
# Fitting 2 layers
# Processing layer-1             done | 00:01:10
# Processing layer-2             done | 00:00:00
# Fit complete                        | 00:01:10
#
# Predicting 2 layers
# Processing layer-1             done | 00:00:00
# Processing layer-2             done | 00:00:00
# Predict complete                    | 00:00:00

# %%
pred_y = predictions_sl
pred_y = np.round(pred_y)
pred_y = np.clip(pred_y, 0, 255)

i = 0
for r in range(img_t.shape[0]):
    for c in range(img_t.shape[1]):
        pred_img[r, c] = pred_y[i]
        i = i + 1


result = Image.fromarray(np.uint8(pred_img))
result
# Out:
# <PIL.Image.Image image mode=L size=280x372 at 0x7FB571BC49D0>

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from scipy import stats

# %%
# prep data from image
img_t = asarray(img_cr)
X = np.empty((img_t.shape[0]*img_t.shape[1], 2))
y = np.empty(img_t.shape[0]*img_t.shape[1])
pred_y = np.empty(img_t.shape[0]*img_t.shape[1])
pred_img = np.empty(img_t.shape)

i = 0
for r in range(img_t.shape[0]):
    for c in range(img_t.shape[1]):
        X[i, 0] = r
        X[i, 1] = c
        y[i] = img_t[r, c]
        i = i + 1
poly = PolynomialFeatures(15)
X = poly.fit_transform(X)
X = np.delete(X, 0, axis = 1)

# %%
X = stats.zscore(X, axis = 0)

# %%
X
# Out:
# array([[-1.727401  , -1.72587592, -1.116348  , ..., -0.28741726,
#         -0.32659635, -0.37085773],
#        [-1.727401  , -1.71350405, -1.116348  , ..., -0.28741726,
#         -0.32659635, -0.37085773],
#        [-1.727401  , -1.70113218, -1.116348  , ..., -0.28741726,
#         -0.32659635, -0.37085773],
#        ...,
#        [ 1.727401  ,  1.70113218,  2.22818854, ..., 10.45913221,
#          8.3296347 ,  4.82465587],
#        [ 1.727401  ,  1.71350405,  2.22818854, ..., 10.9745534 ,
#          8.7775497 ,  5.11322362],
#        [ 1.727401  ,  1.72587592,  2.22818854, ..., 11.51270989,
#          9.24690756,  5.41669551]])

# %%
model = Sequential()
model.add(Dense(512, input_shape=(X.shape[1],), activation='relu'))
model.add(Dense(256, activation='sigmoid'))
model.add(Dense(128, activation='linear'))
model.add(Dense(64, activation='sigmoid'))
model.add(Dense(1, activation='linear'))

# %%
model.compile(loss='mse', 
              optimizer='adam', 
              metrics=['mse'])

# %%
model.fit(X, y,
  batch_size=32,
  epochs=10,
  verbose=1,
  validation_split=0.1,
  shuffle=True)
# Out:
# Train on 93744 samples, validate on 10416 samples
# Epoch 1/10
# 93744/93744 [==============================] - 5s 55us/sample - loss: 10648.5499 - mse: 10648.5615 - val_loss: 3110.2217 - val_mse: 3110.2224
# Epoch 2/10
# 93744/93744 [==============================] - 5s 51us/sample - loss: 2306.5479 - mse: 2306.5471 - val_loss: 366.5632 - val_mse: 366.5632
# Epoch 3/10
# 93744/93744 [==============================] - 5s 51us/sample - loss: 397.9336 - mse: 397.9331 - val_loss: 312.6047 - val_mse: 312.6049
# Epoch 4/10
# 93744/93744 [==============================] - 5s 51us/sample - loss: 197.6144 - mse: 197.6146 - val_loss: 141.1583 - val_mse: 141.1583
# Epoch 5/10
# 93744/93744 [==============================] - 5s 51us/sample - loss: 172.2118 - mse: 172.2120 - val_loss: 182.1668 - val_mse: 182.1667
# Epoch 6/10
# 93744/93744 [==============================] - 5s 51us/sample - loss: 163.3559 - mse: 163.3561 - val_loss: 200.9784 - val_mse: 200.9784
# Epoch 7/10
# 93744/93744 [==============================] - 5s 54us/sample - loss: 158.9209 - mse: 158.9208 - val_loss: 113.6460 - val_mse: 113.6460
# Epoch 8/10
# 93744/93744 [==============================] - 5s 52us/sample - loss: 144.3390 - mse: 144.3390 - val_loss: 98.8664 - val_mse: 98.8664
# Epoch 9/10
# 93744/93744 [==============================] - 5s 52us/sample - loss: 150.5387 - mse: 150.5388 - val_loss: 142.1979 - val_mse: 142.1979
# Epoch 10/10
# 93744/93744 [==============================] - 5s 52us/sample - loss: 131.8559 - mse: 131.8560 - val_loss: 120.6691 - val_mse: 120.6691

# %%
pred_y = model.predict(X)
pred_y = np.round(pred_y)
pred_y = np.clip(pred_y, 0, 255)

i = 0
for r in range(img_t.shape[0]):
    for c in range(img_t.shape[1]):
        pred_img[r, c] = pred_y[i]
        i = i + 1


result = Image.fromarray(np.uint8(pred_img))
result
# Out:
# <PIL.Image.Image image mode=L size=280x372 at 0x7FB556FCD550>

# %%
pred_img_nn
# Out:
# array([[196., 196., 196., ..., 197., 197., 197.],
#        [196., 196., 196., ..., 197., 197., 197.],
#        [196., 196., 196., ..., 197., 197., 197.],
#        ...,
#        [ 29.,  29.,  29., ...,  45.,  45.,  45.],
#        [ 29.,  29.,  29., ...,  45.,  45.,  45.],
#        [ 29.,  29.,  29., ...,  45.,  45.,  45.]])

# %%
stack = np.empty(((pred_img.shape[0], pred_img.shape[1], 14)))
stack[:, :, 0] = pred_img_nn
stack[:, :, 1] = lrw
stack[:, :, 2] = pred_img
stack[:, :, 3] = pred_img
stack[:, :, 4] = pred_img
stack[:, :, 5] = pred_img
stack[:, :, 6] = pred_img
stack[:, :, 7] = pred_img
stack[:, :, 8] = pred_img
stack[:, :, 9] = pred_img
stack[:, :, 10] = pred_img
stack[:, :, 11] = pred_img
stack[:, :, 12] = pred_img
stack[:, :, 13] = lrw

# %%
stack = stack.mean(axis = 2)

# %%
result = Image.fromarray(np.uint8(stack))
result
# Out:
# <PIL.Image.Image image mode=L size=280x372 at 0x7FB556D82F50>

# %%
pred_img
# Out:
# array([[199., 199., 199., ..., 202., 202., 202.],
#        [199., 199., 199., ..., 201., 201., 201.],
#        [199., 199., 199., ..., 201., 201., 201.],
#        ...,
#        [ 32.,  31.,  32., ...,  41.,  41.,  41.],
#        [ 32.,  31.,  32., ...,  41.,  41.,  41.],
#        [ 32.,  31.,  32., ...,  41.,  41.,  41.]])

# %%
img_cr
# Out:
# <PIL.Image.Image image mode=L size=280x372 at 0x7FB59908DD50>

# %%
A = np.array([[1, 2, 3], [4, 5, 6]])
A[0:1, :]
# Out:
# array([[1, 2, 3]])

# %%
np.random.binomial(1, 0.5)
# Out:
# 0

# %%
pred_img = np.empty(((img_array.shape[0], img_array.shape[1], iterations)))
pred_img.shape
# Out:
# (372, 280, 1)

# %%
# convert image to array

iterations = 10
block_size_max = 200
img_array = asarray(img_cr)
pred_img = np.empty(((img_array.shape[0], img_array.shape[1], iterations)))

for i in range(iterations):
    pred_img_single = np.empty(img_array.shape)

    d = np.random.binomial(1, 0.5)
    if d == 1:
        img_array = img_array.T
        pred_img_single = pred_img_single.T

    block_size = np.random.choice(range(1, block_size_max))
    print(block_size)
    s = 0
    while s + block_size < img_array.shape[0]:
        p_order = np.random.choice(range(s, s+block_size), size = block_size, replace = False)
        pred_img_single[s:s+block_size, :] = img_array[p_order, :]
        s = s + block_size

    p_order = np.random.choice(range(s, img_array.shape[0]), size = (img_array.shape[0] - s), replace = False)
    pred_img_single[s:img_array.shape[0], :] = img_array[p_order, :]

    if d == 1:
        img_array = img_array.T
        pred_img_single = pred_img_single.T

    pred_img[:, :, i] = pred_img_single

pred_img = pred_img.mean(axis = 2) 
result = Image.fromarray(np.uint8(pred_img))
result
# Out:
# 89
# 106
# 32
# 191
# 86
# 191
# 45
# 83
# 177
# 154
# <PIL.Image.Image image mode=L size=280x372 at 0x7FB561F678D0>

# %%
np.random.choice(range(0, 10), size = 10, replace = False)
# Out:
# array([2, 9, 7, 1, 3, 5, 4, 6, 0, 8])

# %%
img_array = asarray(img_cr)
pred_img = np.empty((img_array.shape[0], img_array.shape[1]))

pred_img[r, c] = np.clip(np.round(np.random.normal(img_array[r, c], 5, 1)), 0, 255)
# Out:
# array([36.15912703])

# %%
np.clip(np.round(np.random.normal(img_array[r, c], 5, 1)), 0, 255)
# Out:
# array([38.])
